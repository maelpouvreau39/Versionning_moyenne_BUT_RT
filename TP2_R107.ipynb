# %%
# programme qui devra calculer la moyenne de notes données en fonction de leur coef

# %%
def moyenne_coef():  
    i = int(input("combien de notes différents avez vous ?"))
    moyenne = 0
    coef_total = 0
    
    for l in range(i):
        notes = input("rentrez les notes de vos ressources")
        coef = input("rentrez respectivement des notes, les coef de vos ressources")
        moyenne += float(notes) * float(coef) 
        coef_total += float(coef)
    return moyenne / coef_total 

moyenne_coef()
# Out:
# combien de notes différents avez vous ? 3
# rentrez les notes de vos ressources 12
# rentrez respectivement des notes, les coef de vos ressources 10
# rentrez les notes de vos ressources 12
# rentrez respectivement des notes, les coef de vos ressources 10
# rentrez les notes de vos ressources 8
# rentrez respectivement des notes, les coef de vos ressources 7
# 10.962962962962964

# %%
def moy_UE1():
    liste_coef=[10,10,7,7,5,6,5,4,2,5,5,20,20,7]
    coef_tot=0
    moy = 0 
    valeur = int(input("Indiquez le nombre de notes que vous avez"))
    liste_note = []
    for k in range(valeur):
        liste_note.append(int(input("Indiquez ici vos notes dans un ordre respectif de vos coef")))
    for i in range(valeur):
        moy += liste_note[i] * liste_coef[i]
        coef_tot += liste_coef[i]
    return moy / coef_tot


moy_UE1()
# Out:
# Indiquez le nombre de notes que vous avez 3
# Indiquez ici vos notes dans un ordre respectif de vos coef 12
# Indiquez ici vos notes dans un ordre respectif de vos coef 12
# Indiquez ici vos notes dans un ordre respectif de vos coef 8
# 10.962962962962964
